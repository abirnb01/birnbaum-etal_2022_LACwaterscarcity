# %% [markdown]
# The code in this Jupyter notebook produces the figures in "Drivers of Physical and Economic Impacts of Water Scarcity in Latin America and the Caribbean."
#
# Please contact abigail.birnbaum@tufts.edu with any questions.

# %% [markdown]
# See https://github.com/flannerydolan/GCAM.surplus/blob/master/R/process_query.R for an explanation by Flannery Dolan of how the scenarios are referenced in the dataframes.
#
# Socioeconomics (soc) and AGLU (ag) dimensions correspond to the respective SSPs (1-5)
#
# If other SSP components (ssp) are linked to soc then ssp = 1. If linked to ag, ssp = 2
#
# Groundwater Availability (gw): Low groundwater (5%) = 1, medium (25%) = 2, high  (40%) = 3
#
# Reservoir Storage (res): restricted = 1, expanded = 2
#
# Earth System Models (esm): gfdl = 1, hadgem = 2, ipsl = 3, miroc = 4, noresm = 5
#
# Land use tax policy (tax): ffict = 1, uct = 2

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch
import seaborn as sns
import numpy as np
from matplotlib.path import Path
import matplotlib.patches as patches
#for not printing warnings
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load in Data

# %%
#Path to where data is kept. Change this to reflect the appropriate location
fpath = '/cluster/tufts/lamontagnelab/abirnb01/LACwaterscarcity/data/'

#load pickle that contains values for scarcity metrics
metrics = pd.read_pickle(fpath+'query_results/scarcity_metrics')

#load in pickle that has basins in LAC
lac_basins = pd.read_pickle(fpath+'map_shapefiles/LAC_basins/lac_basins')

#load in random forest regression results (variable importance scores)
rf_regr = pd.read_pickle(fpath+'CART_results/randomforestregr_results')

#global weighted average water price for each scenario
#for each scenario, calculate the average global water price
glob_wprice = pd.read_pickle(fpath+'query_results/glob_wprice')

#looking at land allocation for two scenarios with ffict vs uct in the rio grande
riogrande_tax_lalloc = pd.read_pickle(fpath+'query_results/riogrande_tax_lalloc')

# %% [markdown]
# # Figure 1: Map of Median and Worst First Percentile for Scarcity Metrics

# %% [markdown]
# Figure 1 is a map of median (in 2015 and 2100) and worst first percentile (in 2100) point values across scenarios for the 40 LAC basins for the three scarcity metrics.

# %%
def map_stat(df,yr,metric,n_val):
    """This function calculates the desired quantile for an input dataframe, year, and metric
    Input:
    df = input dataframe of metrics
    yr = year to calculate statistic for
    metric = metric to calculate statistic for
    n_val = desired quantile (between 0 and 1)
    
    Output:
    dataframe with statistic calculated for the specified yr, metric, n_val
    """
    
    #filter dataframe to year of interest
    df_filt = df[df.year==yr]
    
    #drop duplicate values from dataframe (for scenarios that have same soc, ag but different ssp - these are the same)
    df_filt = df_filt.drop_duplicates(subset=['basin','year','gw','res','tax','soc','ag','esm','scarcity'],keep='first')
        
    #calculate n_val quantile for metric of interest for all basins
    df_stat = df_filt.groupby(['basin'])[metric].quantile(n_val)
    df_stat = pd.DataFrame(df_stat) #convert result from series to dataframe
    
    #get just the basin name and geometry (for mapping) from df_filt
    df_basins = df_filt.filter(['basin','geometry'])
    df_basins = df_basins.drop_duplicates() #drop all the extra rows (so each basin only appears once)
    
    #merge df_basins with df_stat (so mapping is included in stats dataframe)
    df_stat = df_basins.merge(df_stat,on=['basin'])
    
    return df_stat #return df_stat

#merge the metrics dataframe with the lac_basins dataframe
metrics_map = lac_basins.merge(metrics,on=['basin'])

#CALCULATE STATISTICS - MEDIAN for 2015, 2100 for each metric and WORST FIRST PERCENTILE for 2100 for each metric
med_wprice_2015 = map_stat(metrics_map,2015,'price_scenario',0.5) #water price 2015 median
med_profit_2015 = map_stat(metrics_map,2015,'profit_pchange',0.5) #land profit 2015 median
med_wta_2015 = map_stat(metrics_map,2015,'scarcity',0.5) #physical water scarcity 2015 median
med_wprice_2100 = map_stat(metrics_map,2100,'price_scenario',0.5) #water price 2100 median
med_profit_2100 = map_stat(metrics_map,2100,'profit_pchange',0.5) #land profit 2100 median
med_wta_2100 = map_stat(metrics_map,2100,'scarcity',0.5) #physical water scarcity 2100 median
wfp_wprice_2100 = map_stat(metrics_map,2100,'price_scenario',1-0.01) #water price 2100 worst first percentile
wfp_profit_2100 = map_stat(metrics_map,2100,'profit_pchange',0.01) #land profit 2100 worst first percentile
wfp_wta_2100 = map_stat(metrics_map,2100,'scarcity',1-0.01) #physical water scarcity 2100 worst first percentile

# %%
#PLOT STATISTICS ON MAP
#create map
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9)) = plt.subplots(nrows=3, ncols=3,figsize=(14,12))   

#set min and max of colorbars for the first two rows (median) of plot
min14 = min(min(med_wprice_2015['price_scenario']),min(med_wprice_2100['price_scenario'])) #min of 2015, 2100 water price median
max14 = max(max(med_wprice_2015['price_scenario']),max(med_wprice_2100['price_scenario'])) #max of 2015, 2100 water price median
min25 = min(min(med_profit_2015['profit_pchange']),min(med_profit_2100['profit_pchange'])) #min of 2015, 2100 land profit median
max25 = max(max(med_profit_2015['profit_pchange']),max(med_profit_2100['profit_pchange'])) #max of 2015, 2100 land profit median
min36 = min(min(med_wta_2015['scarcity']),min(med_wta_2100['scarcity'])) #min of 2015, 2100 physical water scarcity median
max36 = max(max(med_wta_2015['scarcity']),max(med_wta_2100['scarcity'])) #max of 2015, 2100 physical water scarcity median

#plot water price 2015 median
med_wprice_2015.plot(ax=ax1,column='price_scenario',legend=True,cmap='Greens',edgecolor='#b3b3b3',
              legend_kwds={'label':r'Water Price (\$1975/$km^3$)','orientation':'vertical'},vmin=min14,vmax=max14,)
#plot land profit 2015 median
cbarnorm = mcolors.TwoSlopeNorm(vmin=min25, vmax = max25, vcenter=0) #set divergining colorbar with zero at center
med_profit_2015.plot(ax=ax2,column='profit_pchange',legend=True,cmap='RdBu_r',edgecolor='#b3b3b3',vmin=min25,vmax=max25,
              norm=cbarnorm,legend_kwds={'label':'% Change in Land Profit','orientation':'vertical'})
#plot physical water scarcity 2015 median
med_wta_2015.plot(ax=ax3,column='scarcity',legend=True,cmap='Reds',edgecolor='#b3b3b3',vmin=min36,vmax=max36,
          legend_kwds={'label':'Withdrawal-To-Availability Ratio','orientation':'vertical'})
#plot water price 2100 median
med_wprice_2100.plot(ax=ax4,column='price_scenario',legend=True,cmap='Greens',edgecolor='#b3b3b3',vmin=min14,vmax=max14,
                           legend_kwds={'label':r'Water Price (\$1975/$km^3$)','orientation':'vertical'})
#plot land profit 2100 median
med_profit_2100.plot(ax=ax5,column='profit_pchange',legend=True,cmap='RdBu_r',edgecolor='#b3b3b3',vmin=min25,vmax=max25,
                     norm=cbarnorm, legend_kwds={'label': '% Change in Land Profit','orientation':'vertical'})
#plot physical water scarcity 2100 median
med_wta_2100.plot(ax=ax6,column='scarcity',legend=True,cmap='Reds',edgecolor='#b3b3b3',vmin=min36,vmax=max36,
      legend_kwds={'label':'Withdrawal-To-Availability Ratio','orientation':'vertical'})
#plot water price 2100 worst first percentile
wfp_wprice_2100.plot(ax=ax7,column='price_scenario',legend=True,cmap='Blues',edgecolor='#b3b3b3',
      legend_kwds={'label':r'Water Price (\$1975/$km^3$)','orientation':'vertical'})
#plot land profit 2100 worst first percentile
wfp_profit_2100.plot(ax=ax8,column='profit_pchange',legend=True,cmap='Blues_r',edgecolor='#b3b3b3',
  legend_kwds={'label': '% Change in Land Profit','orientation':'vertical'})
#plot physical water scarcity 2100 worst first percentile
wfp_wta_2100.plot(ax=ax9,column='scarcity',legend=True,cmap='Blues',edgecolor='#b3b3b3',
legend_kwds={'label': 'Withdrawal-To-Availability Ratio','orientation':'vertical'})

#making latitude/longitude text labels smaller
axlbl = fig.axes[1]
ticksizes = axlbl.figure
for i in range(9):
    cb_ax = ticksizes.axes[i]
    cb_ax.tick_params(labelsize=8)

#set titles for rows/columns
ax1.set_ylabel('Baseline\n(2015) Median',size=16,rotation=0,ha='right')
ax4.set_ylabel('End-of-Century\n(2100) Median',size=16,rotation=0,ha='right')
ax7.set_ylabel('End-Of-Century (2100)\nWorst First Percentile',size=16,rotation=0,ha='right')
ax1.set_title('Water Price',size=16)
ax2.set_title('Land Profit',size=16)
ax3.set_title('Physical Water Scarcity',size=16)

#print plot
plt.show()

# %% [markdown]
# # Figure 2: Random Forest Heatmaps for Scarcity Metrics

# %% [markdown]
# Figure 2 is a set of three heatmaps showing the normalized variable importance scores (from random forest regression) for each of the scarcity metrics across all LAC basins

# %%
def rf_regr_heatmap(df,metric,clmap):
    """This function plots the normalized variable importance scores from the random forest regression 
    as a heatmap
    Input:
    df = input dataframe with variable importance scores
    metric = metric to plot on heatmap
    clmap = what colormap to use for plotting
    
    Output:
    df_table = normalized feature importance scores for each metric
    """
    
    #clean up input dataframe to have just the data we need (drop year = 2100, metric, %IncMSE)
    df_table = df.drop(columns=['%IncMSE','metric','year'])
    
    #Normalize the variable importances across basins
    for bs in df_table.basin.unique()[:]: #loop through the basins
        df_filt = df_table[df_table.basin==bs] #select basin 
        sum_val = df_filt['IncNodePurity'].sum() #sum up the raw IncNodePurity variable importance values
        df_table.loc[df_table['basin']==bs,'norm_IncNodePurity'] = df_table['IncNodePurity']/sum_val #normalize
    
    #pivot the dataframe for heatmap plotting
    df_pivot = pd.pivot_table(data=df_table,values='norm_IncNodePurity',index=['basin'],columns=['varnames'])
    
    df_pivot = df_pivot.filter(['ag','soc','ssp','esm','gw','res','tax']) #reorder columns (x-axis) of heatmap
    
    #reorder rows to be generally geographical North to South
    df_pivot = df_pivot.reindex(['Baja California','Mexico-Northwest Coast',
                                 'Rio Grande River','Mexico-Interior','North Gulf',
                                 'Rio Lerma','Rio Verde',
                                 'Pacific Central Coast','Rio Balsas','Papaloapan',
                                 'Isthmus of Tehuantepec','Grijalva-Usumacinta',
                                 'Yucatan Peninsula','Southern Central America',
                                 'Caribbean','Magdalena','Caribbean Coast','Orinoco',
                                 'Northeast South America-South Atlantic Coast',
                                 'Amazon','Tocantins','North Brazil-South Atlantic Coast',
                                 'Parnaiba','East Brazil-South Atlantic Coast','Sao Francisco',
                                 'Uruguay-Brazil-South Atlantic Coast','Colombia-Ecuador-Pacific Coast',
                                 'Peru-Pacific Coast','North Chile-Pacific Coast','South Chile-Pacific Coast',
                                 'La Puna Region','La Plata','Salinas Grandes','Mar Chiquita',
                                 'South America-Colorado','Pampas Region','North Argentina-South Atlantic Coast',
                                 'Negro','Central Patagonia Highlands','South Argentina-South Atlantic Coast'
                                ])
    #PLOT
    plt.figure(figsize=(3,15))
    sns.heatmap(df_pivot,cmap=clmap, 
                cbar_kws={'label':metric,'orientation':'horizontal'},
                xticklabels=['AG','SOC','SSP','ESM','GW','RES','TAX'], yticklabels=True)
    plt.title(metric)
    plt.ylabel('')
    plt.xlabel('')
    plt.show()

    return df_table #return table of dataframe values

# %%
rf_wprice_norm = rf_regr_heatmap(rf_regr[rf_regr.metric=='water_price'],'Water Price','Greens')
rf_profit_norm = rf_regr_heatmap(rf_regr[rf_regr.metric=='land_profit'],'Land Profit','Blues')
rf_wta_norm = rf_regr_heatmap(rf_regr[rf_regr.metric=='wta'],'Physical Water Scarcity','Reds')

# %% [markdown]
# # Figure 3: Map of main drivers across all outcomes

# %% [markdown]
# This code produces Figure 3, the map of main drivers across all outcomes (result from random forest regression)

# %%
def get_first_dim_summed(rf_df,map_df):
    """This function first groups the seven parameters into water demand, water supply, and tax policy categories
    and sums up the normalized variable importance scores for each category. It then identifies the category with 
    the highest variable importance value for each basin/metric in 2100
    
    Inputs:
    rf_df = dataframe with random forest regression results for a metric (variable importance score normalized)
    map_df = dataframe with basin names and geometry
    
    Output:
    stor_df = dataframe with category (water supply, water demand, or tax policy) with highest increase in node 
    purity for each basin in 2100    
    """
    stor_df = pd.DataFrame() #create empty storage dataframe
    
    #dictionary to use
    var_sum = {'soc':'Water Demand','ag':'Water Demand','ssp':'Water Demand',
           'tax':'Tax Policy','gw':'Water Supply','res':'Water Supply','esm':'Water Supply'}

    metrics_map = map_df.merge(rf_df,on=['basin']) #merge map with rf_df
    
    for bs in metrics_map.basin.unique()[:]: #loop through basins
        df_filt = metrics_map[metrics_map.basin==bs]
        df_filt['varnames'] = df_filt['varnames'].map(var_sum) #cateogrize parameters into three groups
        
        new_df = df_filt.groupby(['basin','varnames'])['norm_IncNodePurity'].sum() #sum up across groups
        new_df = new_df.reset_index()
        
        new_df = map_df.merge(new_df,on=['basin']) #add back in shapefile
        
        largest_var = new_df.nlargest(1,'norm_IncNodePurity') #order by largest to smallest variable importance
        stor_df = stor_df.append(largest_var) #store the largest increase in node purity variable importance
        
    return stor_df #return storage dataframe

# %%
stor_wprice_sum = get_first_dim_summed(rf_wprice_norm,lac_basins)
stor_wta_sum = get_first_dim_summed(rf_wta_norm,lac_basins)
stor_profit_sum = get_first_dim_summed(rf_profit_norm,lac_basins)

# %%
#PLOT RESULTS ON MAP
stors = [stor_wprice_sum,stor_profit_sum,stor_wta_sum] #list of primary categories for each basin for each of the metrics
stor_names = ['Water Price','Land Profit','Physical Water Scarcity'] #metric names

#assign colors to the cateogires
cmap_list = ['tomato','steelblue','forestgreen']
cat_list = ['Water Demand','Water Supply','Tax Policy']

for dim in range(len(cat_list)): #create column in each storage dataframe with the correct color from cmap_list
    stor_wprice_sum.loc[stor_wprice_sum.varnames==cat_list[dim],'cmap_color']=cmap_list[dim]
    stor_wta_sum.loc[stor_wta_sum.varnames==cat_list[dim],'cmap_color']=cmap_list[dim]
    stor_profit_sum.loc[stor_profit_sum.varnames==cat_list[dim],'cmap_color']=cmap_list[dim]

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(30,20)) #initialize figure
axes = [ax1,ax2,ax3] #list of axes (3 panel subplot)
    
for i in range(len(axes)): #for each axis
    stor_df = stors[i] #pick storage array (metric)
    
    stor_df.plot(ax=axes[i],color=stor_df['cmap_color'],edgecolor='grey',) #plot on map
    axes[i].set_title(stor_names[i]+' in 2100',fontsize=30) #set title as name of metric

axlbl = fig.axes[1]
ticksizes = axlbl.figure
for i in range(3):
    cb_ax = ticksizes.axes[i]
    cb_ax.tick_params(labelsize=20)
plt.tight_layout()
plt.show()

#plot legend
legend_elements = [
    Patch(facecolor=cmap_list[0], edgecolor=cmap_list[0],label=cat_list[0]),
    Patch(facecolor=cmap_list[1], edgecolor=cmap_list[1],label=cat_list[1]),
    Patch(facecolor=cmap_list[2], edgecolor=cmap_list[2],label=cat_list[2])
    ]
fig, ax = plt.subplots(figsize=(3, 1))
ax.set_axis_off()
ax.legend(handles=legend_elements,loc = 'center',bbox_to_anchor=(0.5, -0.12),fancybox=False, shadow=False, ncol=3)
plt.show()

# %% [markdown]
# # Figure 4: Scatterplots of Severity versus Uncertainity for Scarcity Metrics

# %%
def get_sev_unc(df,glob_wprice):
    """This function calculates severity and uncertainity values for each basin/metric/year combo
    
    Inputs:
    df = input dataframe that contains metric values for each scenario
    glob_wprice = global weighted average water price for each scenario
    
    Outputs:
    res_data = dataframe that contains uncertainty/severity values for each basin/year/metric combo
    """
    #merge metrics with global weighted average water price
    df = df.merge(glob_wprice,on=['year','gw','res','esm','tax','soc','ag','ssp'])
    df['greateravg'] = df['price_scenario'] > 1.1*df['weighted_price_scenario'] #is our water price>global average?
        
    basins = df.basin.unique()[:] #list of basins to loop through
    years = [2100] #list of years to loop through - here we're just looking at 2100

    stats_stor = [] #create empty storage list
    
    for bas in basins: #loop through basins
        for yr in years: #loop through years
            df_filt = df[(df.year==yr) & (df.basin==bas)] #limit df to single basin/year combo to calculate severity/uncertainty
            
            #drop duplicates (ag, soc the same SSP so ssp parameter doesn't matter)
            df_filt = df_filt.drop_duplicates(subset=['basin','year','gw','res','tax','soc','ag','esm','scarcity'],keep='first')
            
            #SEVERITY
            #for water price - severe is % of scenarios with price higher than global mean price for that scenario
            sev_wprice = 100*(np.sum(df_filt['greateravg'])/len(df_filt))
            #for profit - severe is % of scenarios with % profit change <10%
            sev_profit = 100*(len(df_filt[df_filt['profit_pchange']<-5])/len(df_filt))
            #for wta - severe is % of scenarios with wta > 0.4
            sev_wta = 100*(len(df_filt[df_filt['scarcity']>0.4])/len(df_filt))

            #UNCERTAINTY - IQR for each metric (75th percentile - 25th percentile)
            unc_wprice = df_filt['price_scenario'].quantile(0.75) - df_filt['price_scenario'].quantile(0.25)
            unc_profit = df_filt['profit_pchange'].quantile(0.75) - df_filt['profit_pchange'].quantile(0.25)
            unc_wta = df_filt['scarcity'].quantile(0.75) - df_filt['scarcity'].quantile(0.25)

            data_stor = [] #create empty list for storing severity/uncertainity values for each basin
            data_stor.append(bas) #append basin name
            data_stor.append(yr) #append year
            data_stor.append(sev_wprice) #append water price severity
            data_stor.append(sev_profit) #append land profit severity
            data_stor.append(sev_wta) #append physical water scarcity severity  
            data_stor.append(unc_wprice) #append water price uncertainty
            data_stor.append(unc_profit) #append land profit uncertainty
            data_stor.append(unc_wta) #append physical water scarcity uncertainty
    
            stats_stor.append(data_stor) #append data_stor for basin to list that contains all basin results

    res_data = pd.DataFrame(stats_stor) #make stats_stor into dataframe called res_data
    res_data = res_data.rename(columns={0:'basin',1:'year',2:'sev_wprice',3:'sev_profit',4:'sev_wta',
                                        5:'unc_wprice',6:'unc_profit',7:'unc_wta'}) #rename columns of res_data
    return res_data

# %%
df_stats = get_sev_unc(metrics,glob_wprice) #get severity and uncertainty
yr = 2100
stats_yr = df_stats[df_stats.year==yr] #specify that the year is 2100

# %%
#PLOT
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))

sns.scatterplot(ax=ax1,data=stats_yr,x='unc_wprice',y='sev_wprice',s=80,color='forestgreen')
ax1.set_title('Water Price in '+str(yr),fontsize=16)
ax1.set_ylabel('% of scenarios with Water Price > 10% higher than Global Avg.')
ax1.set_xlabel('Interquartile Range')

sns.scatterplot(ax=ax2,data=stats_yr,x='unc_profit',y='sev_profit',s=80,color='steelblue')
ax2.set_title('Land Profit in '+str(yr),fontsize=16)
ax2.set_ylabel('% of scenarios with % Change in Land Profit < -5%')
ax2.set_xlabel('Interquartile Range')

sns.scatterplot(ax=ax3,data=stats_yr,x='unc_wta',y='sev_wta',s=80,color='tomato')
ax3.set_title('Physical Water Scarcity in '+str(yr),fontsize=16)
ax3.set_ylabel('% of senarios with WTA > 0.4')
ax3.set_xlabel('Interquartile Range')

plt.tight_layout()
plt.show()

# %%
#table of results
display(stats_yr.head(40))
# Out:
#                                            basin  year  sev_wprice  \
# 0                                         Amazon  2100    0.000000
# 1                                Baja California  2100    2.225519
# 2                                Caribbean Coast  2100    3.672107
# 3                                      Caribbean  2100    3.968843
# 4                    Central Patagonia Highlands  2100    0.000000
# 5                 Colombia-Ecuador-Pacific Coast  2100    0.000000
# 6               East Brazil-South Atlantic Coast  2100    0.000000
# 7                            Grijalva-Usumacinta  2100    0.000000
# 8                         Isthmus of Tehuantepec  2100    0.000000
# 9                                       La Plata  2100    0.000000
# 10                                La Puna Region  2100    2.930267
# 11                                     Magdalena  2100    0.000000
# 12                                  Mar Chiquita  2100    0.000000
# ...

# %% [markdown]
# # Figure 5: CART trees for physical water scarcity extremes

# %%
Check R script found at: LOCATION LOCATION LOCATION
# Out:
#   File "<ipython-input-15-d198654da39c>", line 1
#     Check R script found at: LOCATION LOCATION LOCATION
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Figure 6: Land Allocation in Rio Grande River Basin

# %%
def land_alloc_tax_plot(df,plt_title):
    """Plot of land allocation for basin in scenarios - add more to this description
    Inputs:
    df = dataframe with land allocation for given water basin through 2100 for a scenario with FFICT and a 
    scenario with UCT (all other parameter assumptions are the same)
    Outputs:
    plot of land allocation change since 2015 for UCT and FFICT
    """
    sectors = df.crop.unique() #list of land types

    #split up land into different categories
    crops = ['Corn','FiberCrop','FodderGrass','FodderHerb',
            'MiscCrop', 'OilCrop','OtherGrain','Rice','Root_Tuber',
            'SugarCrop','Wheat','PalmFruit']
    bmass =  ['biomass_grass','biomass_tree']
    protected_land =  ['ProtectedGrassland','ProtectedShrubland',
            'ProtectedUnmanagedPasture','ProtectedUnmanagedForest']
    forest = ['Forest','UnmanagedForest']
    nonarable = ['Tundra','RockIceDesert','UrbanLand']
    grassshrub =  ['Grassland','Shrubland']
    pasture = ['Pasture','UnmanagedPasture']
    otherarable = ['OtherArableLand']

    landtype_list = [crops,bmass,protected_land,forest,nonarable,grassshrub,pasture,otherarable]
    landtype_list_name = ['Crops','Biomass','Protected Land','Forest (not protected)','Non-Arable Land',
                         'Grassland/Shrubland','Pasture','Other Arable Land']

    #categorize each land use by type
    df['land_type'] = ''
    for i in range(len(landtype_list[:])):
        df.loc[df['crop'].isin(landtype_list[i]),'land_type'] = landtype_list_name[i]

    df_group = df.groupby(['Units','year','basin','tax','land_type'])['value'].sum() #sum across land types
    df_group = df_group.reset_index()
    
    df_uct = df_group[(df_group.tax=='uct') & (df_group.year>=2015)]
    df_ffict = df_group[(df_group.tax=='ffict') & (df_group.year>=2015)]

    #get 2015 value
    for i in range(len(landtype_list_name)):
        val2015_uct = df_uct[(df_uct['land_type']==landtype_list_name[i]) & (df_uct['year']==2015)]['value'].iloc[0]
        val2015_ffict = df_ffict[(df_ffict['land_type']==landtype_list_name[i]) & (df_ffict['year']==2015)]['value'].iloc[0]
        df_uct.loc[df_uct['land_type']==landtype_list_name[i],'val_2015'] = val2015_uct
        df_ffict.loc[df_ffict['land_type']==landtype_list_name[i],'val_2015'] = val2015_ffict

    df_uct['pchange_2015'] = 100*((df_uct['value'] - df_uct['val_2015'])/df_uct['val_2015'])
    df_ffict['pchange_2015'] = 100*((df_ffict['value'] - df_ffict['val_2015'])/df_ffict['val_2015'])

    df_uct['pchange_2015'] = df_uct['pchange_2015'].fillna(0)
    df_ffict['pchange_2015'] = df_ffict['pchange_2015'].fillna(0)
    
    fig,(ax1,ax2)  = plt.subplots(1,2,figsize=(10,5),sharey=True)
    axes = [ax1,ax2]
    dfs = [df_uct,df_ffict]
    for i in range(len(axes)):
        if i == 0:
            sns.lineplot(ax=axes[i],data=dfs[i],x='year',y='pchange_2015',hue='land_type',palette='Set2',lw=2,legend=False)
        else:
            sns.lineplot(ax=axes[i],data=dfs[i],x='year',y='pchange_2015',hue='land_type',palette='Set2',lw=2,legend=True)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('% Change in Land Allocation from 2015')
    ax1.set_title('UCT Scenario')
    ax2.set_title('FFICT Scenario')
    plt.legend(title='Land Allocation')
    plt.suptitle(plt_title,size=16)
    plt.show()

# %%
land_alloc_tax_plot(riogrande_tax_lalloc,'Rio Grande') 
# to note: biomass production decreases to zero by 2100 (% change is inf since dividing by zero)

# %% [markdown]
# # Figure 7: CART Trees for water price extremes

# %% [markdown]
# # Figure 8: CART tree for land profit extremes

# %% [markdown]
# # Figure 9: Parallel axis plot for  all metrics extreme (Mexico-Northwest Coast)

# %%
def pap_extreme(df,bs,yr):
    """This function plots a parallel axis plot.
    DESCRIBE MORE"""
    
    df_filt = df[(df.basin==bs) & (df.year==yr)] #filter input dataframe to basin and year of interest

    #remove duplicates (when ag = soc and all else equal, ssp parameter doesn't matter)
    df_filt = df_filt.drop_duplicates(['tax','esm','res','gw','soc','ag','scarcity'])
    
    p = np.quantile(df_filt['profit_pchange'],0.05)    #calculate extreme land prfit threshold
    
    #scenario is extreme for all three metrics
    df_filt['all_true'] = ((df_filt['profit_pchange'] <= p) & #land profit is extreme
                            (df_filt['scarcity']>0.4) &  #physical water scarcity is extreme
                           (df_filt['price_scenario']>1.1*df_filt['weighted_price_scenario'])) #water price is extreme
    df_filt = df_filt.reset_index()
    df_filt = df_filt.drop('index',axis=1)
    
    indices = df_filt.index
    i_true = indices[df_filt['all_true']==True]
    i_false = indices[df_filt['all_true']==False]
    
    # ADAPTED CODE from https://stackoverflow.com/questions/8230638/parallel-coordinates-plot-in-matplotlib
    fig, host = plt.subplots(figsize=(15,8))

    # organize the data
    ynames = ['AGLU','LUD','SOC','RES','ESM','OTHER SSP','GW']

    # turn columns into arrays
    ag = df_filt['ag'].to_numpy()
    tax = df_filt['tax'].to_numpy()
    soc = df_filt['soc'].to_numpy()
    res = df_filt['res'].to_numpy()
    esm = df_filt['esm'].to_numpy()
    ssp = df_filt['ssp'].to_numpy()
    gw = df_filt['gw'].to_numpy()

    ys = np.dstack([ag,tax,soc,res,esm,ssp,gw])[0]

    # min and max axes values
    ymins = ys.min(axis=0)
    ymaxs = ys.max(axis=0)
    dys = ymaxs - ymins

    # ymins = ymins - dys * 0.05  # add 5% padding below and above
    # ymaxs = ymaxs + dys * 0.05
    # dys = ymaxs - ymins

    # transform all data to be compatible with the main axis
    zs = np.zeros_like(ys)
    zs[:, 0] = ys[:, 0]
    zs[:, 1:] = (ys[:, 1:] - ymins[1:]) / dys[1:] * dys[0] + ymins[0]


    #plotting
    axes = [host] + [host.twinx() for i in range(ys.shape[1] - 1)]
    for i, ax in enumerate(axes):
        ax.set_ylim(ymins[i], ymaxs[i])
        ax.spines['top'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        if ax != host:
            ax.spines['left'].set_visible(False)
            ax.yaxis.set_ticks_position('right')
            ax.spines["right"].set_position(("axes", i / (ys.shape[1] - 1)))

        #properly label the axes
        if (i==0 or i==2):
            ax.set_yticks([1,2,3,4,5])
            ax.set_yticklabels(['SSP1','SSP2','SSP3','SSP4','SSP5'],fontsize=16)
        elif i==1:
            ax.set_yticks([1,2])
            ax.set_yticklabels(['FFICT','UCT'],fontsize=16)
        elif i==3:
            ax.set_yticks([1,2])
            ax.set_yticklabels(['Restricted','Expanded'],fontsize=16)
        elif i==4:
            ax.set_yticks([1,2,3,4,5])
            ax.set_yticklabels(['GFDL','HADGEM2','IPSL','MIROC','NORESM'],fontsize=16)
        elif i==5:
            ax.set_yticks([1,2])
            ax.set_yticklabels(['From SOC','From AGLU'],fontsize=16)
        else:
            ax.set_yticks([1,2,3])
            ax.set_yticklabels(['Low','Med','High'],fontsize=16)

    host.set_xlim(0, ys.shape[1] - 1)
    host.set_xticks(range(ys.shape[1]))
    host.set_xticklabels(ynames, fontsize=20)
    host.tick_params(axis='x', which='major', pad=7)
    host.spines['right'].set_visible(False)
    host.xaxis.tick_top()
    
    count = 0
    count2 = 0
    
    for j in i_false:
        plot_col = 'skyblue'
        count = count+1
        #host.plot(range(ys.shape[1]), zs[j,:], c='skyblue',lw=0.5)
        verts = list(zip([x for x in np.linspace(0, len(ys) - 1, len(ys) * 3 - 2, endpoint=True)],
                            np.repeat(zs[j, :], 3)[1:-1]))
        for x,y in verts:
            codes = [Path.MOVETO] + [Path.CURVE4 for _ in range(len(verts) - 1)]
            path = Path(verts, codes)
            patch = patches.PathPatch(path, facecolor='none', lw=1, edgecolor=plot_col)
            host.add_patch(patch)
        
    for j in i_true:
        plot_col = 'red'
        count2 = count2+1
        #host.plot(range(ys.shape[1]), zs[j,:], c='red',lw=2)

        verts = list(zip([x for x in np.linspace(0, len(ys) - 1, len(ys) * 3 - 2, endpoint=True)],
                         np.repeat(zs[j, :], 3)[1:-1]))
        for x,y in verts:
            codes = [Path.MOVETO] + [Path.CURVE4 for _ in range(len(verts) - 1)]
            path = Path(verts, codes)
            patch = patches.PathPatch(path, facecolor='none', lw=1, edgecolor=plot_col)
            host.add_patch(patch)
#     print(count)
    print(count2)
    #plt.title(bs+' '+str(yr),fontsize=24)
    plt.tight_layout()
    plt.show()

# %%
metrics_glob = metrics.merge(glob_wprice,on=['year','res','esm','tax','soc','ag','ssp','gw'])
pap_extreme(metrics_glob,'Mexico-Northwest Coast',2100)
# Out:
# 10

# %% [markdown]
# # Figure 10: Parallel axis plot for all metrics extreme (Peru-Pacific Coast)

# %%
pap_extreme(metrics_glob,'Peru-Pacific Coast',2100)
# Out:
# 74
