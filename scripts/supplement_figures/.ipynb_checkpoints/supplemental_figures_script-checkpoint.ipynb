# %% [markdown]
# The code in this Jupyter notebook produces the supplemental figures in "Drivers of Physical and Economic Impacts of Water Scarcity in Latin America and the Caribbean."
#
# Please contact abigail.birnbaum@tufts.edu with any questions.

# %% [markdown]
# # Import Statements

# %%
# These are the packages required for this code. Make sure that they're installed in your Python 3 environment
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
#for not printing warnings
import warnings; warnings.simplefilter('ignore')
import numpy as np
import matplotlib.colors as mcolors

# %% [markdown]
# # Supplemental Figure 1: Map of LAC basins

# %% [markdown]
# Supplemental Figure 1 was made in ArcGIS Pro. The shapefile for Latin America basins can be found at
# LACwaterscarcity/data/map_shapefiles/LAC_basins/lac_basins.shp

# %% [markdown]
#  # Supplemental Figure 2: Runoff for different ESMs

# %% [markdown]
# Plot runoff for the different ESMs under restricted reservoir storage assumptions

# %%
lac_runoff = pd.read_pickle('/cluster/tufts/lamontagnelab/abirnb01/LACwaterscarcity/data/query_results/LAC_runoff')

# %%
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5,figsize=(20,5))
axes = [ax1,ax2,ax3,ax4,ax5]

basins = ['Rio Grande River','North Chile-Pacific Coast','Peru-Pacific Coast','Rio Verde','Mexico-Northwest Coast']

for i in range(len(axes)):
    b = basins[i]
    sns.lineplot(ax=axes[i],data=lac_runoff[(lac_runoff.basin==b) & (lac_runoff.res=='rs')],x='year',y='value',hue='esm',
                palette='Set2',hue_order=['gfdl','hadgem','ipsl','miroc','noresm'],lw=2,legend=False)
    axes[i].set_title(b,size=16)
    axes[i].set_ylabel('')
    axes[i].set_xlabel('')
    if i == 0:
        axes[i].legend(title='Earth Systems Model',labels=['GFDL','HADGEM','IPSL','MIROC','NORESM'])
        axes[i].set_ylabel('Maximum Available Runoff ($km^3$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Supplemental Figure 3: North Chile-Pacific Coast Ag Production (by SOC)

# %%
#load in ag production dataset
fpath = '/cluster/tufts/lamontagnelab/abirnb01/LACwaterscarcity/data/query_results/'
agprod_ncpc = pd.read_pickle(fpath+'ag_production_ncpc') #ag production in North Chile-Pacific Coast basin

# %%
#ag production in NCPC: sum across technologies
agprod_ncpc = agprod_ncpc.groupby(['Units','sector','output','year','gw','res','esm','tax','ssp','ag','soc'])['value'].sum()
agprod_ncpc = agprod_ncpc.reset_index()

# %%
#get ag production for five scenarios that share all parameter assumptions except SOC
agprod_soc = agprod_ncpc[(agprod_ncpc.ssp==2)&
                        (agprod_ncpc.ag==5)&
                         (agprod_ncpc.tax==1)&
                         (agprod_ncpc.esm==1)&
                         (agprod_ncpc.gw==1)&
                         (agprod_ncpc.res==1)]

# %%
#sum up across sectors - exclude biomass, forest, and pasture
agprod_soc_sum = agprod_soc[~(agprod_soc['sector'].isin(['biomass','Pasture','Forest']))]
agprod_soc_sum = agprod_soc_sum.groupby(['Units','year','soc'])['value'].sum()
agprod_soc_sum = agprod_soc_sum.reset_index()

# %%
sns.lineplot(data=agprod_soc_sum,x='year',y='value',hue='soc',lw=2,palette='Set2')
plt.xlabel('')
plt.ylabel('Crop Production ('+agprod_soc_sum['Units'].iloc[0]+')')
plt.title('Crop Production in North Chile-Pacific Coast')
plt.legend(title='SOC',labels=['SSP1','SSP2','SSP3','SSP4','SSP5'])
plt.show()

# %% [markdown]
# # Supplemental Figure 4: North Chile-Pacific Coast Crop Efficiency

# %%
#load in data
fpath = '/cluster/tufts/lamontagnelab/abirnb01/LACwaterscarcity/data/query_results/'
agprod_glob = pd.read_pickle(fpath+'glob_ag_prod') #global ag production
#agprod_ncpc is already loaded for supplemental figure 3
lalloc_glob = pd.read_pickle(fpath+'land_crop') #global land allocation
lalloc_ncpc = pd.read_pickle(fpath+'land_alloc_ncpc') #land allocation in North Chile-Pacific Coast basin

# %%
#simplify North Chile-Pacific Coast (NCPC) land allocation

#sum across regions
lalloc_ncpc = lalloc_ncpc.groupby(['Units','scenario','landleaf','year','gw','res','esm','tax','ssp','ag','soc'])['value'].sum()
lalloc_ncpc = lalloc_ncpc.reset_index()

#split up landleaf
lalloc_ncpc[['crop','basin','wtype','wlevel']] = lalloc_ncpc['landleaf'].str.rsplit('_',n=3,expand=True)

#sum across wtype/wlevel
lalloc_ncpc = lalloc_ncpc.groupby(['Units','scenario','year','gw','ssp','res','esm','tax','soc','ag','crop','basin'])['value'].sum()
lalloc_ncpc = lalloc_ncpc.reset_index()
lalloc_ncpc = lalloc_ncpc.rename(columns={'crop':'sector','value':'lalloc_basin'})

#merge landleaf for ncpc with global landleaf
lalloc_glob = lalloc_glob.rename(columns={'landleaf':'sector','value':'lalloc_glob'}) #rename global landleaf

#merge
lalloc_merge = lalloc_glob.merge(lalloc_ncpc,on=['Units','scenario','sector','year','gw',
                                          'res','esm','soc','ag','tax','gw','ssp'],suffixes=['_glob','_basin'])

#ag production in NCPC: sum across technologies - done above for supplemental figure 3
#agprod_ncpc = agprod_ncpc.groupby(['Units','sector','output','year','gw','res','esm','tax','ssp','ag','soc'])['value'].sum()
#agprod_ncpc = agprod_ncpc.reset_index()

#merge NCPC basin and global ag production
agprod_merge = agprod_glob.merge(agprod_ncpc,on=['Units','sector','output','year','gw','res','esm',
                                                'tax','ssp','ag','soc'],suffixes=['_glob','_basin'])

#now merge land allocation with ag production
lalloc_agprod = lalloc_merge.merge(agprod_merge,on=['sector','year','gw','res','esm','tax','ssp',
                                                   'ag','soc'],suffixes=['_lalloc','_agprod'])

#now limit to just crops with highest production in NCPC (MiscCrop and FodderHerb)
lalloc_agprod_lim = lalloc_agprod[lalloc_agprod.sector.isin(['MiscCrop','FodderHerb'])]

#let's calculate efficiency --> production/land allocation
lalloc_agprod_lim['crop_efficiency_basin'] = lalloc_agprod_lim['value_basin']/lalloc_agprod_lim['lalloc_basin']
lalloc_agprod_lim['crop_efficiency_glob'] = lalloc_agprod_lim['value_glob']/lalloc_agprod_lim['lalloc_glob']

# %%
#now plot crop efficiency in 2100 for these two crops
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(15,5))
sns.scatterplot(data=lalloc_agprod_lim[(lalloc_agprod_lim['sector']=='FodderHerb') & (lalloc_agprod_lim['year']==2100)],
               x='crop_efficiency_glob',y='crop_efficiency_basin',ax=ax1,color='steelblue')
sns.scatterplot(data=lalloc_agprod_lim[(lalloc_agprod_lim['sector']=='MiscCrop') & (lalloc_agprod_lim['year']==2100)],
               x='crop_efficiency_glob',y='crop_efficiency_basin',ax=ax2,color='steelblue')

#plot 1:1 lines
xmin,xmax = ax1.get_xlim()
oneone = np.linspace(xmin,xmax,100)
sns.lineplot(oneone,oneone,color='k',style=True, dashes=[(2,2)],ax=ax1,legend=None)    
ax1.set_xlim([xmin,xmax])
xmin,xmax = ax2.get_xlim()
oneone = np.linspace(xmin,xmax,100)
sns.lineplot(oneone,oneone,color='k',style=True, dashes=[(2,2)],ax=ax2,legend=None)    
ax2.set_xlim([xmin,xmax])

#titles and labels
ax1.set_title('Fodder Herb Efficiency')
ax1.set_ylabel('North Chile-Pacific Coast Prod./Land Alloc.')
ax1.set_xlabel('Global Prod./Land Alloc.')
ax2.set_title('Misc Crop Efficiency')
ax2.set_ylabel('North Chile-Pacific Coast Prod./Land Alloc.')
ax2.set_xlabel('Global Prod./Land Alloc.')
plt.show()

# %% [markdown]
# # Supplemental Figure 5: North Chile-Pacific Coast Land Allocation in 2100

# %%
def land_type(df):
    """ Function to categorize each land allocation into land types"""
    #split up land into different categories
    crops = ['Corn','FiberCrop','FodderGrass','FodderHerb',
            'MiscCrop', 'OilCrop','OtherGrain','Rice','Root_Tuber',
            'SugarCrop','Wheat','PalmFruit']
    bmass =  ['biomass_grass','biomass_tree']
    protected_land =  ['ProtectedGrassland','ProtectedShrubland',
            'ProtectedUnmanagedPasture','ProtectedUnmanagedForest']
    forest = ['Forest','UnmanagedForest']
    nonarable = ['Tundra','RockIceDesert','UrbanLand']
    grassshrub =  ['Grassland','Shrubland']
    pasture = ['Pasture','UnmanagedPasture']
    otherarable = ['OtherArableLand']

    landtype_list = [crops,bmass,protected_land,forest,nonarable,grassshrub,pasture,otherarable]
    landtype_list_name = ['Crops','Biomass','Protected Land','Forest (not protected)','Non-Arable Land',
                         'Grassland/Shrubland','Pasture','Other Arable Land']

    #categorize each land use by type
    df['land_type'] = ''
    for i in range(len(landtype_list[:])):
        df.loc[df['sector'].isin(landtype_list[i]),'land_type'] = landtype_list_name[i]
    return df

# %%
#PLOT BOXPLOT OF LAND ALLOCATION IN 2100
lalloc_ncpc_sum = land_type(lalloc_ncpc)
lalloc_ncpc_sum = lalloc_ncpc_sum.groupby(['Units','scenario','year','gw','ssp','res','esm',
                                         'tax','soc','ag','land_type'])['lalloc_basin'].sum()
lalloc_ncpc_sum = lalloc_ncpc_sum.reset_index()

fig = plt.figure(figsize=(20,4))
sns.boxplot(data=lalloc_ncpc_sum[lalloc_ncpc_sum.year==2100],y='lalloc_basin',x='land_type',color='steelblue')
plt.xlabel('')
plt.ylabel('Land Allocation ($km^3$)')
plt.title('North Chile-Pacific Coast Land Allocation in 2100')
# Out:
# Text(0.5, 1.0, 'North Chile-Pacific Coast Land Allocation in 2100')

# %% [markdown]
# # Supplemental Figure 6: Peru Pacific Coast Land Allocation for Specific Scenarios

# %%
def land_alloc_tax_plot(df,plt_title):
    """Plot of land allocation for basin in scenarios - add more to this description
    Inputs:
    df = dataframe with land allocation for given water basin through 2100 for a scenario with FFICT and a 
    scenario with UCT (all other parameter assumptions are the same)
    Outputs:
    plot of land allocation change since 2015 for UCT and FFICT
    """
    sectors = df.crop.unique() #list of land types

    #split up land into different categories
    crops = ['Corn','FiberCrop','FodderGrass','FodderHerb',
            'MiscCrop', 'OilCrop','OtherGrain','Rice','Root_Tuber',
            'SugarCrop','Wheat','PalmFruit']
    bmass =  ['biomass_grass','biomass_tree']
    protected_land =  ['ProtectedGrassland','ProtectedShrubland',
            'ProtectedUnmanagedPasture','ProtectedUnmanagedForest']
    forest = ['Forest','UnmanagedForest']
    nonarable = ['Tundra','RockIceDesert','UrbanLand']
    grassshrub =  ['Grassland','Shrubland']
    pasture = ['Pasture','UnmanagedPasture']
    otherarable = ['OtherArableLand']

    landtype_list = [crops,bmass,protected_land,forest,nonarable,grassshrub,pasture,otherarable]
    landtype_list_name = ['Crops','Biomass','Protected Land','Forest (not protected)','Non-Arable Land',
                         'Grassland/Shrubland','Pasture','Other Arable Land']

    #categorize each land use by type
    df['land_type'] = ''
    for i in range(len(landtype_list[:])):
        df.loc[df['crop'].isin(landtype_list[i]),'land_type'] = landtype_list_name[i]

    df_group = df.groupby(['Units','year','basin','tax','land_type'])['value'].sum() #sum across land types
    df_group = df_group.reset_index()
    
    df_uct = df_group[(df_group.tax=='uct') & (df_group.year>=2015)]
    df_ffict = df_group[(df_group.tax=='ffict') & (df_group.year>=2015)]

    #get 2015 value
    for i in range(len(landtype_list_name)):
        val2015_uct = df_uct[(df_uct['land_type']==landtype_list_name[i]) & (df_uct['year']==2015)]['value'].iloc[0]
        val2015_ffict = df_ffict[(df_ffict['land_type']==landtype_list_name[i]) & (df_ffict['year']==2015)]['value'].iloc[0]
        df_uct.loc[df_uct['land_type']==landtype_list_name[i],'val_2015'] = val2015_uct
        df_ffict.loc[df_ffict['land_type']==landtype_list_name[i],'val_2015'] = val2015_ffict

    df_uct['pchange_2015'] = 100*((df_uct['value'] - df_uct['val_2015'])/df_uct['val_2015'])
    df_ffict['pchange_2015'] = 100*((df_ffict['value'] - df_ffict['val_2015'])/df_ffict['val_2015'])

    df_uct['pchange_2015'] = df_uct['pchange_2015'].fillna(0)
    df_ffict['pchange_2015'] = df_ffict['pchange_2015'].fillna(0)
    
    fig,(ax1,ax2)  = plt.subplots(1,2,figsize=(10,5),sharey=True)
    axes = [ax1,ax2]
    dfs = [df_uct,df_ffict]
    for i in range(len(axes)):
        if i == 0:
            sns.lineplot(ax=axes[i],data=dfs[i],x='year',y='pchange_2015',hue='land_type',palette='Set2',lw=2,legend=False)
        else:
            sns.lineplot(ax=axes[i],data=dfs[i],x='year',y='pchange_2015',hue='land_type',palette='Set2',lw=2,legend=True)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('% Change in Land Allocation from 2015')
    ax1.set_title('UCT Scenario')
    ax2.set_title('FFICT Scenario')
    plt.legend(title='Land Allocation',loc='lower left')
    plt.suptitle(plt_title,size=16)
    plt.show()

# %%
ppc_tax_lalloc = pd.read_pickle(fpath+'perupacificcoast_tax_lalloc')
land_alloc_tax_plot(ppc_tax_lalloc,'Peru-Pacific Coast')

# %% [markdown]
# # Supplemental Figure 7: Peru Pacific Coast Ag Production (under different SOC assumptions)

# %%
ppc_agprod_ag = pd.read_pickle(fpath+'perupacificcoast_ag_agprod')#ag production in NCPC: sum across technologies

#sum across technologies
ppc_agprod_ag_sum = ppc_agprod_ag.groupby(['Units','sector','output','year','ag'])['value'].sum()
ppc_agprod_ag_sum = ppc_agprod_ag_sum.reset_index()

#sum up across sectors - exclude biomass, forest, and pasture
ppc_agprod_ag_sum = ppc_agprod_ag_sum[~(ppc_agprod_ag_sum['sector'].isin(['biomass','Pasture','Forest']))]
ppc_agprod_ag_sum = ppc_agprod_ag_sum.groupby(['Units','year','ag'])['value'].sum()
ppc_agprod_ag_sum = ppc_agprod_ag_sum.reset_index()

#plot production
sns.lineplot(data=ppc_agprod_ag_sum,x='year',y='value',hue='ag',lw=2,palette='Set2')
plt.xlabel('')
plt.ylabel('Crop Production ('+ppc_agprod_ag_sum['Units'].iloc[0]+')')
plt.title('Crop Production in Peru-Pacific Coast')
plt.legend(title='AG',labels=['SSP1','SSP2','SSP3','SSP4','SSP5'])
plt.show()

# %% [markdown]
# # Supplemental Figure 8: Land Allocation in 2100 in Mexico-Northwest Coast basin

# %%
mnc_tax_lalloc = pd.read_pickle(fpath+'mexiconorthwestcoast_tax_lalloc')
land_alloc_tax_plot(mnc_tax_lalloc,'Mexico-Northwest Coast')

# %% [markdown]
# # Supplemental Figure 9: Earth Systems Model in Mexico Northwest Coast basin

# %%
#load in price and production data 
mnc_esm_agprice = pd.read_pickle(fpath+'mexiconorthwestcoast_esm_agprice')
mnc_esm_agprod = pd.read_pickle(fpath+'mexiconorthwestcoast_esm_agprod')

# %%
#sum up ag production across subsectors
mnc_esm_agprod_sum = mnc_esm_agprod.groupby(['Units','scenario','region','sector','year'])['value'].sum()
mnc_esm_agprod_sum = mnc_esm_agprod_sum.reset_index()

#merge the two dataframes
mnc_esm_agrev = mnc_esm_agprice.merge(mnc_esm_agprod_sum,on=['scenario','region','sector','year'],
                                     suffixes=['_price','_prod'])

# %%
#to calculate revenue, multiply value_price by value_prod by 10**9
mnc_esm_agrev['value_rev'] = mnc_esm_agrev['value_price']*mnc_esm_agrev['value_prod']*(10**9)

#then sum across regions to get basin revenue, by sector
mnc_esm_agrev_basin = mnc_esm_agrev.groupby(['sector','year','esm'])['value_rev'].sum()
mnc_esm_agrev_basin = mnc_esm_agrev_basin.reset_index()

#sum across sectors
mnc_esm_agrev_sum = mnc_esm_agrev_basin.groupby(['year','esm'])['value_rev'].sum() 
mnc_esm_agrev_sum = mnc_esm_agrev_sum.reset_index()

# %%
#get biomass production
mnc_esm_bmass = mnc_esm_agrev[mnc_esm_agrev.sector=='biomass']
#sum across regions (Mexico and USA)
mnc_esm_bmass = mnc_esm_bmass.groupby(['Units_prod','scenario','sector','year','esm'])['value_prod'].sum()
mnc_esm_bmass = mnc_esm_bmass.reset_index()

# %%
#get production of other crops
mnc_esm_crops = mnc_esm_agrev[~(mnc_esm_agrev['sector'].isin(['biomass','Forest','Pasture']))] #not biomass, forest, pasture
#sum across regions and sectors
mnc_esm_crops = mnc_esm_crops.groupby(['Units_prod','scenario','year','esm'])['value_prod'].sum()
mnc_esm_crops = mnc_esm_crops.reset_index()

# %%
#3-panel plot of crop production, biomass production, and total revenue
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))

#plot other crop production (not pasture or forest)
sns.lineplot(ax=ax1,data=mnc_esm_crops[mnc_esm_crops.year>=2020],x='year',y='value_prod',hue='esm',palette='Set2',
             legend=False)
ax1.set_title('Crop Production')
ax1.set_ylabel('Crop Production ('+mnc_esm_crops['Units_prod'].iloc[0]+')')
ax1.set_xlabel('')

#plot biomass production
sns.lineplot(ax=ax2,data=mnc_esm_bmass[mnc_esm_bmass.year>=2020],x='year',y='value_prod',hue='esm',palette='Set2',
             legend=False)
ax2.set_title('Biomass Production')
ax2.set_ylabel('Biomass Production ('+mnc_esm_bmass['Units_prod'].iloc[0]+')')
ax2.set_xlabel('')
#plt.legend(title='ESM',labels=['GFDL','HADGEM','IPSL','MIROC','NORESM'])


#Plot total revenue
sns.lineplot(ax=ax3,data=mnc_esm_agrev_sum[(mnc_esm_agrev_sum.year>=2020)],x='year',y='value_rev',palette='Set2',
             hue='esm')
ax3.set_title('Agriculture Revenue')
ax3.set_ylabel('Agriculture Revenue ($1975)')
ax3.set_xlabel('')
ax3.legend(title='ESM',labels=['GFDL','HADGEM','IPSL','MIROC','NORESM'])

plt.suptitle('Mexico-Northwest Coast',size=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Supplemental figure S10: map of global biomass production

# %%
bm_esm_glob = pd.read_pickle(fpath+'mexiconorthwestcoast_esm_glob_bmass')
allregions = gpd.read_file('/cluster/tufts/lamontagnelab/abirnb01/LACwaterscarcity/data/map_shapefiles/all_regions/all_regions.shp')

# %%
#merge global biomass with allregions
allregions = allregions.rename(columns={'reg_nm':'region'})
allregions = allregions.drop(['key','reg_id'],axis=1)
bm_esm = allregions.merge(bm_esm_glob,on=['region'])
bm_esm = bm_esm[bm_esm.year==2100]

# %%
#isolate the value for the gfdl esm
bm_esm['gfdl_val'] = 0
reg_list = bm_esm.region.unique()[:]

for i in range(len(reg_list)):
    regval = reg_list[i]
    gfdlval = bm_esm[(bm_esm.region==regval) & 
                               (bm_esm.esm=='gfdl')]['value'].iloc[0]

    bm_esm.loc[bm_esm['region']==regval,'gfdl_val'] = gfdlval
    
bm_esm['gfdl_diff'] = 100*(bm_esm['value']-bm_esm['gfdl_val'])/(bm_esm['gfdl_val'])

fig, (ax1,ax2,ax3,ax4) = plt.subplots(1, 4,figsize=(20,5))

axes = [ax1,ax2,ax3,ax4]
mexiconorthwestcoast_ag_agprodmexiconorthwestcoast_ag_agprod
esm_list = ['hadgem','ipsl','miroc','noresm']

norm = mcolors.TwoSlopeNorm(vmin=bm_esm['gfdl_diff'].min(),
                              vmax = bm_esm['gfdl_diff'].max(), vcenter=0)

#norm = mcolors.TwoSlopeNorm(vmin=-60,vmax=60,vcenter=0)

for i in range(len(esm_list)):
    esmval = esm_list[i]
    df_filt = bm_esm[bm_esm['esm']==esmval]
    df_filt.plot(column='gfdl_diff',ax=axes[i],legend=True, cmap='RdBu_r',norm=norm,
                 legend_kwds={'label': 'Percent Change from GFDL Biomass Production in 2100 (%)',
                        'orientation': 'horizontal'},
                )
    axes[i].set_title(str.upper(esm_list[i]))
plt.show()

# %% [markdown]
# # supplemental figure S11: ag production under SSP ag assumptions in Mexico-Northwest Coast

# %%
mnc_agprod_ag = pd.read_pickle(fpath+'mexiconorthwestcoast_ag_agprod')

#sum across technologies
mnc_agprod_ag_sum = mnc_agprod_ag.groupby(['Units','sector','output','year','ag'])['value'].sum()
mnc_agprod_ag_sum = mnc_agprod_ag_sum.reset_index()

#sum up across sectors - exclude biomass, forest, and pasture
mnc_agprod_ag_sum = mnc_agprod_ag_sum[~(mnc_agprod_ag_sum['sector'].isin(['biomass','Pasture','Forest']))]
mnc_agprod_ag_sum = mnc_agprod_ag_sum.groupby(['Units','year','ag'])['value'].sum()
mnc_agprod_ag_sum = mnc_agprod_ag_sum.reset_index()

#plot production
sns.lineplot(data=mnc_agprod_ag_sum[mnc_agprod_ag_sum.year>=2015],x='year',y='value',hue='ag',lw=2,palette='Set2')
plt.xlabel('')
plt.ylabel('Crop Production ('+mnc_agprod_ag_sum['Units'].iloc[0]+')')
plt.title('Crop Production in Mexico-Northwest Coast')
plt.legend(title='AG',labels=['SSP1','SSP2','SSP3','SSP4','SSP5'])
plt.show()

# %% [markdown]
# # Supplemental figure S12: ag production under SSP soc assumptions in Mexico-Northwest Coast

# %%
mnc_agprod_soc = pd.read_pickle(fpath+'mexiconorthwestcoast_soc_agprod')

#sum across technologies
mnc_agprod_soc_sum = mnc_agprod_soc.groupby(['Units','sector','output','year','soc'])['value'].sum()
mnc_agprod_soc_sum = mnc_agprod_soc_sum.reset_index()

#sum up across sectors - exclude biomass, forest, and pasture
mnc_agprod_soc_sum = mnc_agprod_soc_sum[~(mnc_agprod_soc_sum['sector'].isin(['biomass','Pasture','Forest']))]
mnc_agprod_soc_sum = mnc_agprod_soc_sum.groupby(['Units','year','soc'])['value'].sum()
mnc_agprod_soc_sum = mnc_agprod_soc_sum.reset_index()

#plot production
sns.lineplot(data=mnc_agprod_soc_sum[mnc_agprod_soc_sum.year>=2015],x='year',y='value',hue='soc',lw=2,palette='Set2')
plt.xlabel('')
plt.ylabel('Crop Production ('+mnc_agprod_soc_sum['Units'].iloc[0]+')')
plt.title('Crop Production in Mexico-Northwest Coast')
plt.legend(title='SOC',labels=['SSP1','SSP2','SSP3','SSP4','SSP5'])
plt.show()
